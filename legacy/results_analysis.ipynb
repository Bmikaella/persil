# %%
import pandas as pd 
from os import listdir
from os.path import join

# %%
trait = 'introverted'
results = pd.read_csv(f'mpr_baseline2/results_baseline2_{trait}_run2.csv', index_col=0)
results_filtered2 = results[(results.test_f1 > 0.1) & (results.mbti_trait == trait)].iloc[:, ]

# %%
results_filtered.append(results_filtered2)
# Out:
#    models_name                           hash_id   mbti_trait  fold  \
# 6    baseline2  c2102d3f1db464c0a3ffd647ef9a0428  introverted     0
# 15   baseline2  c00d96c37199ceeef99e79116f3808e4  introverted     1
# 19   baseline2  fdd86ffbc1d5b21c50b4e37bcc1dba6c  introverted     2
# 29   baseline2  1035be053ea933f3794a1532a99af12e  introverted     3
# 37   baseline2  92291bf7bb2453e2d629b7382e4e0df4  introverted     4
# 0    baseline2  101e1167ec1bc6496f7bc49b43c6c23d  introverted     0
# 1    baseline2  b7bc5634408eb3a27f4af9575590d801  introverted     0
# 2    baseline2  101e1167ec1bc6496f7bc49b43c6c23d  introverted     0
# 3    baseline2  b7bc5634408eb3a27f4af9575590d801  introverted     0
# 4    baseline2  101e1167ec1bc6496f7bc49b43c6c23d  introverted     0
# 5    baseline2  101e1167ec1bc6496f7bc49b43c6c23d  introverted     0
# 6    baseline2  b7bc5634408eb3a27f4af9575590d801  introverted     0
# 7    baseline2  101e1167ec1bc6496f7bc49b43c6c23d  introverted     0
# ...

# %%
df = df.append(resutls_thinking[(resutls_thinking.test_f1 > 0.5) & (resutls_thinking.mbti_trait == 'thinking')].iloc[:, ])
# Out:
# /home/mbosnjak/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df = pd.read_csv('mpr_baseline_take2_twin/results_FINAL_all_traits.csv')

# %%
df[['test_f1', 'epoch', 'mbti_trait']]
# Out:
#      test_f1  epoch   mbti_trait
# 0   0.636167   74.0     thinking
# 1   0.603020   85.0     thinking
# 2   0.648464   70.0     thinking
# 3   0.630913   75.0     thinking
# 4   0.653564   79.0     thinking
# 5   0.529169   66.0   perceiving
# 6   0.496455   47.0   perceiving
# 7   0.548291  116.0   perceiving
# 8   0.522704   96.0   perceiving
# 9   0.504944   14.0   perceiving
# 10  0.514959   44.0  introverted
# 11  0.521271   25.0  introverted
# 12  0.515707    0.0  introverted
# 13  0.506401   25.0  introverted
# 14  0.496102   20.0  introverted
# 15  0.490173    0.0    intuitive
# 16  0.502363   42.0    intuitive
# 17  0.488366   48.0    intuitive
# 18  0.486175    2.0    intuitive
# 19  0.511436   44.0    intuitive

# %%
resutls_thinking = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_thiksda.csv', index_col=0)
resutls_thinking[(resutls_thinking.test_f1 > 0.5) & (resutls_thinking.mbti_trait == 'thinking')].iloc[:, ]
#resutls_perceiving = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_perceivingIK.csv', index_col=0)
#resutls_perceiving[(resutls_perceiving.test_f1 > 0.45) & (resutls_perceiving.mbti_trait == 'perceiving')].iloc[:, ]
#resutls_introverted = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_thinkingREDH.csv', index_col=0)
#resutls_introverted[(resutls_introverted.test_f1 > 0.45) & (resutls_introverted.mbti_trait == 'introverted')].iloc[:, :]
#resutls_intuitive = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_intuitiveHLA.csv', index_col=0)
#resutls_intuitive[(resutls_intuitive.test_f1 > 0.2) & (resutls_intuitive.mbti_trait == 'intuitive')].iloc[:, :]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-37d80dbb4cf3> in <module>
# ----> 1 resutls_thinking = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_thiksda.csv', index_col=0)
#       2 resutls_thinking[(resutls_thinking.test_f1 > 0.5) & (resutls_thinking.mbti_trait == 'thinking')].iloc[:, ]
#       3 #resutls_perceiving = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_perceivingIK.csv', index_col=0)
#       4 #resutls_perceiving[(resutls_perceiving.test_f1 > 0.45) & (resutls_perceiving.mbti_trait == 'perceiving')].iloc[:, ]
#       5 #resutls_introverted = pd.read_csv('mpr_baseline_take2_twin/results_baseline_take2_twin_thinkingREDH.csv', index_col=0)
#
# ...

# %%
resutls_thinking = pd.read_csv('mpr_baseline3/results_baseline3_introverted_run3.csv', index_col=0)
resutls_thinking[(resutls_thinking.test_f1 > 0.5) & (resutls_thinking.mbti_trait == 'thinking')].iloc[:, ]
# Out:
#    models_name                           hash_id mbti_trait  fold  \
# 20   baseline3  9f1cc7f37f1ebedb84cdd6d4b6a61c50   thinking     0
#
#     learning_rate  batch_size  kernels_count  sentences_count  hidden_layer1  \
# 20        0.00001          64             12                4             12
#
#     alpha  ...  val_recall_1  val_recall_macro  test_f1  test_precision_0  \
# 20  0.001  ...      0.781893          0.656768  0.64534          0.569024
#
#     test_precision_1  test_precision_macro  test_recall_0  test_recall_1  \
# 20          0.731057              0.650041       0.511346        0.77425
#
#     test_recall_macro  epoch
# 20           0.642798  111.0
#
# [1 rows x 28 columns]
