# %%
import numpy as np
import pandas as pd 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
import torch as to
import torch.nn as nn 
import torch.nn.functional as func
from torch.utils import data
from torch.utils.data import DataLoader
import random 
import time 
import torch.nn.utils.rnn as rnnutils
from sklearn.model_selection import train_test_split
import torchviz
from torchsummary import summary
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score 
from itertools import tee
import hashlib
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Info
# This notebook is a continuation of the 'baseline.ipynb' nootebook.
#
# ### Setup
# +> Added balancing of the data-set. Balancing is done in a way that samples are added until the less frequent class isn't same as more frequent class. Samples are added squentialy, not randomly, thus ensuring that the differenece of the most frequent sample and least frequent sample in the data-set is one.
#
# +> f1 is now macro
#
# +> batchnormalization was added befor convolution and removed :D
#
# +> we are currently stopping the training if f1 is not changing (max_constant_f1 denotes the max number of epochs that the f1 is not changing)
#
# +> additonal data was added to the results dataframe (precision and recall for each class)
#
# +> to ease the strain on memory this code has all input data is represented as indices, thus it runs a bit slower because it has to access the input dataframe to attain input vectors
#
# +> original dataframe is preprocesed and deleted so that memory is freed
#
# +> now you can specify a gpu, ouput of all results, predictions and models (CONSTANT: 'MODELS_NAME')

# %%
#CELL METADATA
DATASET = '/home/mbosnjak/Datasets/embedded_comments_last_100_min_20com_per_auth_w_wc_10_200_no_mbti.csv'
FOLDS = '/home/mbosnjak/Datasets/comments_last_100_min_20com_per_auth_w_wc_10_200.csv.folds.csv'
AUTHORS = '/home/mbosnjak/Datasets/author_profiles.csv'

MODELS_NAME = 'baseline_take2'
OUTPUT_DIR = f'mpr_{MODELS_NAME}/'
RESULTS = OUTPUT_DIR + f'results_{MODELS_NAME}.csv'

RELEVANT_DIFFERENCE = 0.0000001
NUMBER_OF_CLASSES = 2
STATE = 156
no_of_folds = 2
cuda_device_index = 0

mbti_labels_1 = ['introverted', 'intuitive']
mbti_labels_2 = ['thinking', 'perceiving']
mbti_labels = [mbti_labels_1[0]] #+ mbti_labels_2
MODELS_PREFORMANCE_COLUMNS = ['val_f1', 'val_precision_0', 'val_precision_1', 'val_precision_macro' ,\
                              'val_recall_0', 'val_recall_1', 'val_recall_macro', \
                              'test_f1', 'test_precision_0', 'test_precision_1', 'test_precision_macro',\
                              'test_recall_0', 'test_recall_1', 'test_recall_macro',\
                              'epoch']
MODELS_PARAMETER_COLUMNS = ['mbti_trait', 'fold', 'learning_rate', 'batch_size',\
                           'kernels_count', 'sentences_count' ]
MODELS_META_DATA_COLUMNS = ['models_name', 'hash_id']
to.manual_seed(STATE)

# %%
#CELL PARAMETERS
batch_sizes = [16, 32, 64]
learning_rates = [0.00001, 0.000001, 0.0000005, 0.0000001, 0.00000005]
kernel_sizes = [8, 12, 16]
sentences_counts = [2, 4, 6]
n_epochs = 90
use_GPU = True
#TODO: this is sentences per author not comments per author, quick fix is max size 200*100 (200 max sentences by comment * 100 comments)
comments_per_author = 20000
#comments_per_author = 20
cuda_device = to.device(cuda_device_index) if use_GPU else None
validation_p = .2
print_status_batch = 1000
max_constant_f1 = 2

# %%
def get_checkpoints_name(models_identifier):
    return OUTPUT_DIR+"save_"+MODELS_NAME+'_'+models_identifier + ".pt"

def get_predictions_file_name(models_identifier, target, fold):
    return OUTPUT_DIR + f'{target}_{fold}_{MODELS_NAME}_{models_identifier}_predictions'

def delimiter():
    print('-'*23)

# %%
input_df = pd.read_csv(DATASET)
#input_df = pd.read_csv(DATASET, nrows = 2000) # TODO: remove nrows
folds_df = pd.read_csv(FOLDS, usecols =['author', 'fold'])
authors_profiles_df = pd.read_csv(AUTHORS)
authors_with_mbti = list(authors_profiles_df[authors_profiles_df.introverted.notnull()]['author'])

# %%
#TODO: add comment delimiter -> to recognize comments end and beginning
def merger(comments):
    npad = [(0, max(sentences_counts)), (0, 0)]
    carpet = comments[:comments_per_author].as_matrix(columns=comments.columns[1:1025])
    carpet_padded = np.pad(carpet, pad_width=npad, mode='constant', constant_values=0)
    #print(f'before {carpet.shape} - after {carpet_padded.shape}')
    return to.tensor(carpet_padded)

# %%
#Data preparation
#data_df = input_df[input_df['author'].isin(authors_with_mbti)]
#del input_df
#present_authors = sorted(data_df['author'].unique())
#authors_indices = dict(zip(present_authors , list(range(len(present_authors)))))
input_x_df = data_df.groupby(['author']).apply(merger).tolist()
del data_df
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     724             try:
# --> 725                 result = self._python_apply_general(f)
#     726             except Exception:
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     218
# --> 219         for key, (i, group) in zip(group_keys, splitter):
#     220             object.__setattr__(group, "name", key)
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/ops.py in __iter__(self)
#     898     def __iter__(self):
# --> 899         sdata = self._get_sorted_data()
#     900
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _get_sorted_data(self)
#     917     def _get_sorted_data(self):
# --> 918         return self.data.take(self.sort_idx, axis=self.axis)
#     919
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3603         new_data = self._data.take(
# -> 3604             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3605         )
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1396         return self.reindex_indexer(
# -> 1397             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1398         )
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#
# MemoryError: Unable to allocate array with shape (1024, 2202312) and data type float64
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-78ec745a749b> in <module>
#       4 #present_authors = sorted(data_df['author'].unique())
#       5 #authors_indices = dict(zip(present_authors , list(range(len(present_authors)))))
# ----> 6 input_x_df = data_df.groupby(['author']).apply(merger).tolist()
#       7 del data_df
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     735
#     736                 with _group_selection_context(self):
# --> 737                     return self._python_apply_general(f)
#     738
#     739         return result
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     740
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#     744         return self._wrap_applied_output(
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _selected_obj(self)
#     496         if self._selection is None or isinstance(self.obj, Series):
#     497             if self._group_selection is not None:
# --> 498                 return self.obj[self._group_selection]
#     499             return self.obj
#     500         else:
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2990             indexer = np.where(indexer)[0]
#    2991
# -> 2992         data = self.take(indexer, axis=1)
#    2993
#    2994         if is_single_key:
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3602
#    3603         new_data = self._data.take(
# -> 3604             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3605         )
#    3606         result = self._constructor(new_data).__finalize__(self)
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1395         new_labels = self.axes[axis].take(indexer)
#    1396         return self.reindex_indexer(
# -> 1397             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1398         )
#    1399
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1355                             axis=0,
#    1356                             new_mgr_locs=mgr_locs,
# -> 1357                             fill_tuple=None,
#    1358                         )
#    1359                     )
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# ~/.conda/envs/pero/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1714             out = np.empty(out_shape, dtype=dtype, order="F")
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#    1718     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate array with shape (1024, 2202312) and data type float64

# %%
results = pd.DataFrame(data=None, columns=MODELS_META_DATA_COLUMNS+MODELS_PREFORMANCE_COLUMNS+MODELS_PARAMETER_COLUMNS)
for name in MODELS_PREFORMANCE_COLUMNS:
    results = results.astype({name: 'float64'})

# %%
resutls = pd.read_csv('mpr_baseline_take2/results_baseline_take2.csv',  index_col=0)

# %%
def set_hash(index):
    global results
    identifier = hashlib.md5(''.join([str(x) for x in results[MODELS_PARAMETER_COLUMNS].iloc[index]]).encode('utf-8')).hexdigest()
    results.at[index, 'hash_id'] = identifier
    return identifier

def create_new_model_input(mbti_trait, fold, learning_rate, batch_size,\
                           kernels_count, sentences_count):
    global results
    results = results.append({'models_name':MODELS_NAME, 'mbti_trait' : mbti_trait, 'fold' : fold, 'learning_rate' : learning_rate, 'batch_size' : batch_size, 'kernels_count' : kernels_count, 'sentences_count' : sentences_count}, ignore_index=True)
    return set_hash(len(results)-1)    

def update_models_val_results(models_identifier, val_f1, val_precision_0, val_precision_1, val_precision_m, val_recall_0, val_recall_1, val_recall_m, epoch):
    global results
    results.loc[results['hash_id'] == models_identifier, 'val_f1'] = val_f1
    results.loc[results['hash_id'] == models_identifier, 'val_precision_0'] = val_precision_0
    results.loc[results['hash_id'] == models_identifier, 'val_precision_1'] = val_precision_1
    results.loc[results['hash_id'] == models_identifier, 'val_precision_macro'] = val_precision_m
    results.loc[results['hash_id'] == models_identifier, 'val_recall_0'] = val_recall_0
    results.loc[results['hash_id'] == models_identifier, 'val_recall_1'] = val_recall_1
    results.loc[results['hash_id'] == models_identifier, 'val_recall_macro'] = val_recall_m
    results.loc[results['hash_id'] == models_identifier, 'epoch'] = epoch
    
def update_models_test_results(models_identifier, test_f1, test_precision_0, test_precision_1, precision_m, test_recall_0, test_recall_1, test_recall_m):
    global results
    results.loc[results['hash_id'] == models_identifier, 'test_f1'] = test_f1
    results.loc[results['hash_id'] == models_identifier, 'test_precision_0'] = test_precision_0
    results.loc[results['hash_id'] == models_identifier, 'test_precision_1'] = test_precision_1
    results.loc[results['hash_id'] == models_identifier, 'test_precision_macro'] = test_precision_m
    results.loc[results['hash_id'] == models_identifier, 'test_recall_0'] = test_recall_0
    results.loc[results['hash_id'] == models_identifier, 'test_recall_1'] = test_recall_1
    results.loc[results['hash_id'] == models_identifier, 'test_recall_macro'] = test_recall_m
    
def get_best_models_data(target, fold):
    return results.loc[results[(results.mbti_trait == target) & (results.fold == fold)]['val_f1'].idxmax()]

# %%
create_new_model_input('dfsfdsf',333,3,223333,1,13)
# Out:
# 'e5a677ccc00e12a5dc84842655a04262'

# %%
results
# Out:
#         models_name                           hash_id    val_f1  \
# 0    baseline_take2  e5a677ccc00e12a5dc84842655a04262       NaN
# 1    baseline_take2  e36ae0804472af283afbd748b7cc30e9  0.440665
# 2    baseline_take2  2f4e282eb0a31414afec1306d8c24742  0.175029
# 3    baseline_take2  eb66caa5ee9eb650d51577d0a28f7fe2  0.440665
# 4    baseline_take2  2bb3311afd88c876e4c191400a913072  0.440665
# ..              ...                               ...       ...
# 141  baseline_take2  5b27ff53feb4f2bf11f666f6dc4e45cc  0.440665
# 142  baseline_take2  b7007e14266db7c6997a0309c265bb70  0.440665
# 143  baseline_take2  e4504e69c4c25b2dcf922902c1560d0e  0.440665
# 144  baseline_take2  e95b2e301c1a3c1985001f0379bbc17c  0.175029
# 145  baseline_take2  1dd25e247afc839aa6632b716f5ba7d4       NaN
#
#      val_precision_0  val_precision_1  val_precision_macro  val_recall_0  \
# 0                NaN              NaN                  NaN           NaN
# 1           0.000000         0.787836             0.393918           0.0
# 2           0.212164         0.000000             0.106082           1.0
# 3           0.000000         0.787836             0.393918           0.0
# 4           0.000000         0.787836             0.393918           0.0
# ..               ...              ...                  ...           ...
# 141         0.000000         0.787836             0.393918           0.0
# 142         0.000000         0.787836             0.393918           0.0
# 143         0.000000         0.787836             0.393918           0.0
# 144         0.212164         0.000000             0.106082           1.0
# 145              NaN              NaN                  NaN           NaN
#
#      val_recall_1  val_recall_macro  test_f1  ...  test_recall_0  \
# 0             NaN               NaN      NaN  ...            NaN
# 1        0.787836               0.5      NaN  ...            NaN
# 2        0.000000               0.5      NaN  ...            NaN
# 3        0.787836               0.5      NaN  ...            NaN
# 4        0.787836               0.5      NaN  ...            NaN
# ..            ...               ...      ...  ...            ...
# 141      0.787836               0.5      NaN  ...            NaN
# 142      0.787836               0.5      NaN  ...            NaN
# 143      0.787836               0.5      NaN  ...            NaN
# 144      0.000000               0.5      NaN  ...            NaN
# 145           NaN               NaN      NaN  ...            NaN
#
#      test_recall_1  test_recall_macro  epoch   mbti_trait  fold  \
# 0              NaN                NaN    NaN      dfsfdsf   333
# 1              NaN                NaN    0.0  introverted     0
# 2              NaN                NaN    0.0  introverted     0
# 3              NaN                NaN    0.0  introverted     0
# 4              NaN                NaN    0.0  introverted     0
# ..             ...                ...    ...          ...   ...
# 141            NaN                NaN    0.0  introverted     0
# 142            NaN                NaN    0.0  introverted     0
# 143            NaN                NaN    0.0  introverted     0
# 144            NaN                NaN    0.0  introverted     0
# 145            NaN                NaN    NaN  introverted     0
#
#      learning_rate batch_size kernels_count sentences_count
# 0                3     223333             1              13
# 1            0.001          1             4               2
# 2             0.01          1             4               2
# 3           0.0001          1             4               2
# 4            1e-05          1             4               2
# ..             ...        ...           ...             ...
# 141          1e-07          4            16               4
# 142          1e-08          4            16               4
# 143          1e-09          4            16               4
# 144          1e-10          4            16               4
# 145          0.001         16             4               2
#
# [146 rows x 23 columns]

# %% [markdown]
# ### FLOW

# %%
def get_input_output(data_authors, target):
    output_prep = authors_profiles_df[authors_profiles_df['author'].isin(data_authors)][target].tolist()
    input_indices = [index for author, index in authors_indices.items() if author in data_authors]
    return input_indices, output_prep

def balance_binary_data(input_df, output_df):
    positive_indices = [index for index, element in enumerate(output_df) if element == 1.0]
    negative_indices = [index for index, element in enumerate(output_df) if element == 0.0]
    negative_count = len(negative_indices)
    positive_count = len(positive_indices)
    
    if(positive_count > negative_count):
        return create_balanced_data(positive_indices, negative_indices, input_df, output_df)
    elif(negative_count > positive_count):
        return create_balanced_data(negative_indices, positive_indices, input_df, output_df)
        
def create_balanced_data(more_frequent, less_frequent, input_df, output_df):
    more_frequent_count = len(more_frequent)
    less_frequent_count = len(less_frequent)
    constant_multiplyer = more_frequent_count // less_frequent_count
    remaining_additions = more_frequent_count % less_frequent_count
    balanced_indices = less_frequent*constant_multiplyer + less_frequent[:remaining_additions] + more_frequent
    output_df_balanced = [output_df[index] for index in balanced_indices]
    input_df_balanced = [input_df[index] for index in balanced_indices]
    return input_df_balanced, output_df_balanced
    
def data_preparation(target, fold):
    test_data_authors = folds_df[(folds_df['fold'] == fold) & (folds_df['author'].isin(present_authors))]['author'].tolist()
    train_data_authors = folds_df[(folds_df['fold'] != fold) & (folds_df['author'].isin(present_authors))]['author'].tolist()
    train_input_indices, train_output = get_input_output(train_data_authors, target)
    test_input_indices, test_output = get_input_output(test_data_authors, target)

    train_input_indices, val_input_indices, train_output, val_output = train_test_split(train_input_indices, train_output, test_size=validation_p, random_state=STATE)
    assert len(train_input_indices) == len(train_output)
    assert len(test_input_indices) == len(test_output)
    assert len(val_input_indices) == len(val_output)
    train_input_indices, train_output = balance_binary_data(train_input_indices, train_output)
    return train_input_indices, train_output, val_input_indices, val_output, test_input_indices, test_output

def chunks(l, n):
    return [l[i:i + n] for i in range(0, len(l), n)]  

def create_minibatches(data_X, data_y, minibatch_size, cuda_dev):
    for idx_list in chunks(range(len(data_X)), minibatch_size):
        data_X_indices = [data_X[index] for index in idx_list]
        data_y_idx = [int(data_y[index]) for index in idx_list]
        
        minibatch_X = [input_x_df[index] for index in data_X_indices]
        minibatch_X = rnnutils.pad_sequence(minibatch_X, batch_first=True, padding_value = 0) 
        minibatch_X = minibatch_X.unsqueeze(1)
        minibatch_y = to.tensor(data_y_idx)
        if cuda_dev is not None:
            minibatch_X = minibatch_X#.to(device=cuda_dev, dtype=to.float)
            minibatch_y = minibatch_y.to(device=cuda_dev, dtype=to.long)

        yield((minibatch_X, minibatch_y))

# %%
class ConvoCarpet(nn.Module):
    def __init__ (self, embedding_size = 1024, kernels_count=64, sentences_count=2):
        super(ConvoCarpet, self).__init__()
        self.batch_norm = nn.BatchNorm2d(1)
        self.conv_layer = nn.Conv2d(1, kernels_count, [sentences_count, embedding_size])
        self.pool_layer = nn.AdaptiveMaxPool2d((1, None))
        self.fc_layer = nn.Linear(kernels_count, NUMBER_OF_CLASSES)
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, input_batch):
        #normalized_input = self.batch_norm(input_batch)
        conv_output = func.relu(self.conv_layer(input_batch))
        maxpool_output = self.pool_layer(conv_output)
        maxpool_output = maxpool_output.flatten(start_dim=1)
        linear_output = self.fc_layer(maxpool_output)
        output = self.softmax(linear_output)
        #return func.log_softmax(linear_output)
        return output

# %%
def calcMeasures(total_logits, total_true, threshold):
    total_preds = []
    for minibatch_logits in total_logits:
        minibatch_preds = minibatch_logits[:,1] > threshold
        total_preds.append(minibatch_preds)
    total_preds = to.cat(total_preds)
    total_true = to.cat(total_true)
    F1 = f1_score(total_true.cpu(), total_preds.cpu(), pos_label = 1, average='macro')
    precision_m = precision_score(total_true.cpu(), total_preds.cpu(), average='macro')
    precision_1 = precision_score(total_true.cpu(), total_preds.cpu(), pos_label = 1)
    precision_0 = precision_score(total_true.cpu(), total_preds.cpu(), pos_label = 0)
    recall_m = recall_score(total_true.cpu(), total_preds.cpu(), average='macro')
    recall_1 = recall_score(total_true.cpu(), total_preds.cpu(), pos_label = 1)
    recall_0 = recall_score(total_true.cpu(), total_preds.cpu(), pos_label = 0)
    return F1, precision_0, precision_1, precision_m, recall_0, recall_1, recall_m

def apply_model(model, loss_func, data_loader):
    model.eval()
    total_loss = 0
    predicted = []
    true_output = []
    minibatch_loss = 0
    with to.no_grad():
        n_batch = 0
        for inputs, labels in data_loader:
            n_batch += 1
            minibatch_logits = model(inputs.to(device=cuda_device, dtype=to.float))
            minibatch_loss = loss_func(minibatch_logits, labels)
            
            total_loss += minibatch_loss
            predicted.append(minibatch_logits)
            true_output.append(labels)
            
    return total_loss, predicted, true_output

def optimize_models_params(trait, fold, train_input_indices, train_output, val_input_indices, val_output):
    print('Start training ...')
    
    loss = nn.CrossEntropyLoss()
    
    for batch_size in batch_sizes:
        for kernel_size in kernel_sizes:
            for sent_size in sentences_counts:
                for learning_rate in learning_rates:                
                    
                    train_loader = create_minibatches(train_input_indices, train_output, batch_size, cuda_device)
                    val_loader = create_minibatches(val_input_indices, val_output, batch_size, cuda_device)
                    
                    delimiter()
                    delimiter()
                    print(f'Starting training for BS: {batch_size} KS: {kernel_size} SS: {sent_size} LR: {learning_rate}')
                    delimiter()
                    
                    models_identifier = create_new_model_input(trait, fold, learning_rate, batch_size, kernel_size, sent_size)
                    
                    model = ConvoCarpet(kernels_count=kernel_size, sentences_count=sent_size)
                    if use_GPU:
                          model.to(cuda_device)

                    optimizer = to.optim.Adam(model.parameters(), learning_rate, amsgrad = True)

                    train_model(train_loader, val_loader, models_identifier, model, loss, optimizer)
                    results.to_csv(RESULTS)
    

def train_model(train_loader, val_loader, models_identifier, model, loss, optimizer):
    best_f1_val = 0
    last_f1 = 0
    counter = 0
    
    for epoch in range(0, n_epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0
        n_batch = 0
        train_loader, train_loader_backup = tee(train_loader)
        for inputs, labels in train_loader_backup:

            n_batch += 1
            #print(f"Current batch is {n_batch}")

            model.zero_grad()

            logits = model(inputs.to(device=cuda_device, dtype=to.float))
            minibatch_loss = loss(logits, labels)
            total_loss += minibatch_loss
            minibatch_loss.backward()
            optimizer.step()
            if(n_batch % print_status_batch == 0):
                
                delimiter()
                print(f"Train - Epoch {epoch} - batch {n_batch}, batch loss is {minibatch_loss:.6f}, total loss is {total_loss:.6f}")
                delimiter()

                
        delimiter()
        val_loader, val_loader_backup = tee(val_loader)
        val_loss, val_logits, true_val = apply_model(model, loss, val_loader_backup)
        val_f1_score, val_precision_0, val_precision_1, val_precision_m, val_recall_0, val_recall_1, val_recall_m = calcMeasures(val_logits, true_val, 0.5)
        
        
        print(f'Epoch {epoch} end: {time.time()-epoch_start}')
        print(f'Validation loss: {val_loss:.7f} - F1 score: {val_f1_score:.7f}')
        print(f'0 class -> precision: {val_precision_0:.7f} - recall: {val_recall_0:.7f}')
        print(f'1 class -> precision: {val_precision_1:.7f} - recall: {val_recall_1:.7f}')
        print(f'precision: {val_precision_m:.7f} - recall: {val_recall_m:.7f} - MACRO')
        delimiter()
        
        if (abs(val_f1_score - last_f1) <= RELEVANT_DIFFERENCE):
            counter += 1
        else:
            counter = 0
        
        last_f1 = val_f1_score
        
        if(counter >= max_constant_f1):
            return
        
        if (val_f1_score > best_f1_val):
            update_models_val_results(models_identifier, val_f1_score, val_precision_0, val_precision_1, val_precision_m, val_recall_0, val_precision_1, val_recall_m, epoch)
            best_f1_val = val_f1_score
        # save a checkpoint
            best_checkpoint_filename = get_checkpoints_name(models_identifier)
            to.save({
              "models_identifier" : models_identifier, 
              "model_state_dict" : model.state_dict(),
              "optimizer_state_dict" : optimizer.state_dict()
            }, best_checkpoint_filename)

# %%
for target in mbti_labels:
    print(f"Creating model for target: {target}")
    for fold in range(0, no_of_folds):
        
        print(f'Processing fold {fold}...')
        
        train_input_indices, train_output, val_input_indices, val_output, test_input_indices, test_output = data_preparation(target, fold)
        
        optimize_models_params(target, fold, train_input_indices, train_output, val_input_indices, val_output)
        
        
        best_models = get_best_models_data(target, fold)
        #Recreate model
        models_identifier = best_models['hash_id']
        model = ConvoCarpet(kernels_count=best_models['kernels_count'] , sentences_count=best_models['sentences_count'])
        if use_GPU:
              model.to(cuda_device)

        checkpoint = to.load(get_checkpoints_name(models_identifier))
        model.load_state_dict(checkpoint["model_state_dict"])
        loss = nn.CrossEntropyLoss()

        
        print("."*15)
        print("."*15)
        
        print(f'Apply best model to test for {target} on fold {fold}.')
        test_loader = create_minibatches(test_input_indices, test_output, 1, cuda_device)
        test_loss, test_logits, test_true = apply_model(model, loss, test_loader)
        test_f1_score, test_precision_0, test_precision_1, test_precision_m, test_recall_0, test_recall_1, test_recall_m = calcMeasures(test_logits, test_true, 0.5)
        print(f'Test loss: {test_loss:.5f} - F1 score: {test_f1_score:.7f} ')
        print(f'0 class -> precision: {test_precision_0:.7f} - recall: {test_recall_0:.7f}')
        print(f'1 class -> precision: {test_precision_1:.7f} - recall: {test_recall_1:.7f}')
        print(f'precision: {test_precision_m:.7f} - recall: {test_recall_m:.7f} - MACRO')
              
        update_models_test_results(models_identifier, test_f1_score, test_precision_0, test_precision_1, test_precision_m, test_recall_0, test_recall_1, test_recall_m)
        with open(get_predictions_file_name(models_identifier, target, fold), 'w+') as f:
            for pre_l, true_l in zip(test_logits, test_true):
                f.write(f'{pre_l.cpu()[0][0]}, {pre_l.cpu()[0][1]}, {true_l.cpu().tolist()[0]}\n')
        results.to_csv(RESULTS)
        
        ##Save best models data
        
        print(f"+++ Finished with training and testing model for {target} on fold {fold}. +++")
        
        print("."*15)
        print("."*15)
# Out:
# Creating model for target: introverted
# Processing fold 0...
# Start training ...
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 0.001
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.313275, total loss is 315.320404
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.313270, total loss is 628.598633
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.313265, total loss is 941.888611
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.313263, total loss is 1255.135742
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 1.313251, total loss is 2135.367676
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 0.313284, total loss is 3334.228516
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 0.313265, total loss is 3647.462158
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 0.313267, total loss is 3960.695312
# -----------------------
# -----------------------
# /home/mbosnjak/.conda/envs/pero/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mbosnjak/.conda/envs/pero/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mbosnjak/.conda/envs/pero/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Epoch 0 end: 26.23428225517273
# Validation loss: 742.9553223 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 1.313231, total loss is 1313.236084
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 1.313037, total loss is 2626.452881
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.313349, total loss is 3438.257324
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.313271, total loss is 3751.576660
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 1.313069, total loss is 4631.661621
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 0.313283, total loss is 5156.667969
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 0.313262, total loss is 5470.145996
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 0.313263, total loss is 5783.624023
# -----------------------
# -----------------------
# Epoch 1 end: 24.582770824432373
# Validation loss: 742.9561157 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 1.313256, total loss is 1313.214233
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.313344, total loss is 2478.741211
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.313271, total loss is 2792.168945
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.313262, total loss is 3105.449463
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 1.313153, total loss is 3985.574707
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 0.313276, total loss is 4677.311523
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 0.313264, total loss is 4990.791504
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 0.313271, total loss is 5304.268555
# -----------------------
# -----------------------
# Epoch 2 end: 22.224796533584595
# Validation loss: 742.9536133 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 1.313253, total loss is 1313.217163
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.313281, total loss is 1902.230347
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.313334, total loss is 2215.487793
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.313278, total loss is 2528.735596
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 1.313069, total loss is 3408.960449
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 1.313257, total loss is 4722.155762
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 0.313372, total loss is 5573.303711
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 0.313287, total loss is 5886.882324
# -----------------------
# -----------------------
# Epoch 3 end: 18.281148195266724
# Validation loss: 742.9822998 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 1.296306, total loss is 1312.505493
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.313273, total loss is 1766.012085
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.313263, total loss is 2079.292480
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.313267, total loss is 2392.555664
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 1.313255, total loss is 3272.152344
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 0.313916, total loss is 4067.492920
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 0.313262, total loss is 4381.155762
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 0.313277, total loss is 4694.693848
# -----------------------
# -----------------------
# Epoch 4 end: 20.928110361099243
# Validation loss: 743.0120239 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 0.01
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.313262, total loss is 313.566803
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.313262, total loss is 626.818542
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.313262, total loss is 940.050964
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.313262, total loss is 1253.283447
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 1.313262, total loss is 2133.515869
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 1.313262, total loss is 3446.748291
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 1.313262, total loss is 4760.104004
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 1.313262, total loss is 6073.580566
# -----------------------
# -----------------------
# Epoch 0 end: 29.19765591621399
# Validation loss: 1556.9246826 - F1 score: 0.1750292
# 0 class -> precision: 0.2121641 - recall: 1.0000000
# 1 class -> precision: 0.0000000 - recall: 0.0000000
# precision: 0.1060820 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 0.313262, total loss is 313.262756
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.313262, total loss is 626.514526
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.313262, total loss is 939.746948
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.313262, total loss is 1252.979370
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 1.313262, total loss is 2133.211914
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 1.313262, total loss is 3446.444336
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 1.313262, total loss is 4759.800293
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 1.313262, total loss is 6073.276855
# -----------------------
# -----------------------
# Epoch 1 end: 20.658557891845703
# Validation loss: 1556.9246826 - F1 score: 0.1750292
# 0 class -> precision: 0.2121641 - recall: 1.0000000
# 1 class -> precision: 0.0000000 - recall: 0.0000000
# precision: 0.1060820 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 0.313262, total loss is 313.262756
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.313262, total loss is 626.514526
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.313262, total loss is 939.746948
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.313262, total loss is 1252.979370
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 1.313262, total loss is 2133.211914
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 1.313262, total loss is 3446.444336
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 1.313262, total loss is 4759.800293
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 1.313262, total loss is 6073.276855
# -----------------------
# -----------------------
# Epoch 2 end: 18.622148752212524
# Validation loss: 1556.9246826 - F1 score: 0.1750292
# 0 class -> precision: 0.2121641 - recall: 1.0000000
# 1 class -> precision: 0.0000000 - recall: 0.0000000
# precision: 0.1060820 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 0.313262, total loss is 313.262756
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.313262, total loss is 626.514526
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.313262, total loss is 939.746948
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.313262, total loss is 1252.979370
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 1.313262, total loss is 2133.211914
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 1.313262, total loss is 3446.444336
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 1.313262, total loss is 4759.800293
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 1.313262, total loss is 6073.276855
# -----------------------
# -----------------------
# Epoch 3 end: 18.398540019989014
# Validation loss: 1556.9246826 - F1 score: 0.1750292
# 0 class -> precision: 0.2121641 - recall: 1.0000000
# 1 class -> precision: 0.0000000 - recall: 0.0000000
# precision: 0.1060820 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 0.313262, total loss is 313.262756
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.313262, total loss is 626.514526
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.313262, total loss is 939.746948
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.313262, total loss is 1252.979370
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 1.313262, total loss is 2133.211914
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 1.313262, total loss is 3446.444336
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 1.313262, total loss is 4759.800293
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 1.313262, total loss is 6073.276855
# -----------------------
# -----------------------
# Epoch 4 end: 21.709839820861816
# Validation loss: 1556.9246826 - F1 score: 0.1750292
# 0 class -> precision: 0.2121641 - recall: 1.0000000
# 1 class -> precision: 0.0000000 - recall: 0.0000000
# precision: 0.1060820 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 0.0001
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.631565, total loss is 675.469177
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.589135, total loss is 1285.442017
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.551750, total loss is 1855.402832
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.520298, total loss is 2390.909180
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 0.320063, total loss is 2950.385010
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 0.313658, total loss is 3265.638428
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 0.313590, total loss is 3579.570068
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 0.313409, total loss is 3893.236572
# -----------------------
# -----------------------
# Epoch 0 end: 27.951355695724487
# Validation loss: 743.0339966 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 1.312371, total loss is 1312.066528
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.507722, total loss is 2305.622803
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.484142, total loss is 2801.217529
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.464905, total loss is 3275.413574
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 0.315053, total loss is 3833.781982
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 0.313832, total loss is 4148.280273
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 0.313453, total loss is 4461.970703
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 0.313498, total loss is 4775.538086
# -----------------------
# -----------------------
# Epoch 1 end: 18.312333583831787
# Validation loss: 742.9983521 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 1.312528, total loss is 1312.325073
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.456531, total loss is 2199.475586
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.442111, total loss is 2648.654053
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.430064, total loss is 3084.561768
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 0.315974, total loss is 3641.056641
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 0.313902, total loss is 3955.576172
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 0.313396, total loss is 4269.319336
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 0.313436, total loss is 4582.892090
# -----------------------
# -----------------------
# Epoch 2 end: 18.132140636444092
# Validation loss: 742.9992065 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 1.312512, total loss is 1312.330444
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.425583, total loss is 2215.975342
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.416072, total loss is 2636.779297
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.407938, total loss is 3048.677734
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 0.315648, total loss is 3595.943115
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 0.313866, total loss is 3910.662598
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 0.313548, total loss is 4224.463379
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 0.313491, total loss is 4538.075684
# -----------------------
# -----------------------
# Epoch 3 end: 18.02345371246338
# Validation loss: 743.0032959 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 1.311998, total loss is 1312.124023
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.404505, total loss is 2156.538086
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.397925, total loss is 2557.777100
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.392182, total loss is 2952.773438
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 0.315601, total loss is 3501.155762
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 0.313666, total loss is 3815.904297
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 0.313461, total loss is 4129.723145
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 0.313528, total loss is 4443.342773
# -----------------------
# -----------------------
# Epoch 4 end: 18.764456272125244
# Validation loss: 742.9989624 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 1e-05
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.342846, total loss is 388.284698
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.319851, total loss is 716.238708
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.316290, total loss is 1036.611450
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.317108, total loss is 1354.382324
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 1.298206, total loss is 2229.355957
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 0.941232, total loss is 3468.073486
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 0.444963, total loss is 4053.368896
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 0.360413, total loss is 4456.652344
# -----------------------
# -----------------------
# Epoch 0 end: 24.160812377929688
# Validation loss: 756.4996948 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 0.975402, total loss is 1128.484985
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.402886, total loss is 1828.565796
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.326954, total loss is 2184.100586
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.323438, total loss is 2512.814453
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 1.263344, total loss is 3376.072021
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 0.615733, total loss is 4340.745117
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 0.429434, total loss is 4829.950684
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 0.366289, total loss is 5229.457031
# -----------------------
# -----------------------
# Epoch 1 end: 18.280452489852905
# Validation loss: 759.4663696 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 1.014601, total loss is 1127.337402
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.414882, total loss is 1869.953003
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.328193, total loss is 2234.401123
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.325792, total loss is 2566.489258
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 1.255677, total loss is 3425.688965
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 0.571174, total loss is 4361.253906
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 0.417865, total loss is 4824.686523
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 0.363111, total loss is 5215.522461
# -----------------------
# -----------------------
# Epoch 2 end: 18.37078022956848
# Validation loss: 758.3159790 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 1.034184, total loss is 1138.924438
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.400296, total loss is 1869.799805
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.326222, total loss is 2231.341064
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.326816, total loss is 2562.926270
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 1.252434, total loss is 3422.103516
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 0.545098, total loss is 4354.729004
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 0.409091, total loss is 4801.349609
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 0.360304, total loss is 5185.299805
# -----------------------
# -----------------------
# Epoch 3 end: 18.745917797088623
# Validation loss: 757.2067871 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 1.046213, total loss is 1148.283081
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.388684, total loss is 1857.843750
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.327460, total loss is 2217.765381
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.329253, total loss is 2550.107910
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 1.255066, total loss is 3408.614502
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 0.528600, total loss is 4345.580566
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 0.401217, total loss is 4780.615234
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 0.356322, total loss is 5158.833496
# -----------------------
# -----------------------
# Epoch 4 end: 18.54200577735901
# Validation loss: 756.2778320 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 1e-06
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.638304, total loss is 654.578857
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.580839, total loss is 1262.580566
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.545214, total loss is 1828.649536
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.528368, total loss is 2356.894287
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 0.881856, total loss is 3094.245361
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 0.792810, total loss is 3958.393799
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 0.770539, total loss is 4759.737793
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 0.762810, total loss is 5506.577148
# -----------------------
# -----------------------
# Epoch 0 end: 20.33595848083496
# Validation loss: 968.5943604 - F1 score: 0.4948691
# 0 class -> precision: 0.2057971 - recall: 0.2366667
# 1 class -> precision: 0.7857811 - recall: 0.7540395
# precision: 0.4957891 - recall: 0.4953531 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 0.667331, total loss is 683.840942
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.612287, total loss is 1322.508057
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.581240, total loss is 1922.170654
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.561566, total loss is 2487.368408
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 0.845351, total loss is 3210.255371
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 0.749854, total loss is 4029.085938
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 0.736614, total loss is 4793.176758
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 0.731116, total loss is 5507.477051
# -----------------------
# -----------------------
# Epoch 1 end: 17.937804222106934
# Validation loss: 947.9859619 - F1 score: 0.4601991
# 0 class -> precision: 0.2352941 - recall: 0.0266667
# 1 class -> precision: 0.7884058 - recall: 0.9766607
# precision: 0.5118500 - recall: 0.5016637 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 0.692531, total loss is 709.853027
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.634873, total loss is 1373.118652
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.604988, total loss is 1995.662354
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.584844, total loss is 2581.934082
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 0.826244, total loss is 3297.903564
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 0.727394, total loss is 4091.047852
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 0.716417, total loss is 4832.193848
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 0.711073, total loss is 5525.700684
# -----------------------
# -----------------------
# Epoch 2 end: 17.923816919326782
# Validation loss: 934.7645874 - F1 score: 0.4402217
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7875354 - recall: 0.9982047
# precision: 0.3937677 - recall: 0.4991023 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 0.708915, total loss is 727.262268
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.648978, total loss is 1407.043213
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.621292, total loss is 2044.835938
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.597089, total loss is 2645.038574
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 0.811831, total loss is 3356.624512
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 0.714269, total loss is 4132.880371
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 0.704231, total loss is 4858.824219
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 0.697042, total loss is 5538.603516
# -----------------------
# -----------------------
# Epoch 3 end: 17.640053033828735
# Validation loss: 926.3845825 - F1 score: 0.4404432
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7876858 - recall: 0.9991023
# precision: 0.3938429 - recall: 0.4995512 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 0.719744, total loss is 738.560181
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.658570, total loss is 1429.394531
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.632536, total loss is 2077.380127
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.605634, total loss is 2686.724121
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 0.802006, total loss is 3395.390137
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 0.704361, total loss is 4160.402344
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 0.697310, total loss is 4876.046875
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 0.687948, total loss is 5546.554688
# -----------------------
# -----------------------
# Epoch 4 end: 18.05858612060547
# Validation loss: 920.7738037 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 1000, batch loss is 0.727187, total loss is 746.031799
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 2000, batch loss is 0.663943, total loss is 1444.259766
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 3000, batch loss is 0.640916, total loss is 2099.083496
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 4000, batch loss is 0.611070, total loss is 2714.380127
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 5000, batch loss is 0.794508, total loss is 3420.997559
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 6000, batch loss is 0.697827, total loss is 4178.418457
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 7000, batch loss is 0.692114, total loss is 4887.084961
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 8000, batch loss is 0.682237, total loss is 5551.217285
# -----------------------
# -----------------------
# Epoch 5 end: 18.14493465423584
# Validation loss: 916.9003906 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 1000, batch loss is 0.731932, total loss is 750.854980
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 2000, batch loss is 0.666483, total loss is 1453.720459
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 3000, batch loss is 0.646333, total loss is 2112.793213
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 4000, batch loss is 0.614410, total loss is 2731.639893
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 5000, batch loss is 0.788653, total loss is 3436.857910
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 6000, batch loss is 0.693613, total loss is 4189.333984
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 7000, batch loss is 0.688942, total loss is 4893.168945
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 8000, batch loss is 0.678281, total loss is 5552.807129
# -----------------------
# -----------------------
# Epoch 6 end: 18.83996033668518
# Validation loss: 914.1541138 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 1000, batch loss is 0.734503, total loss is 754.180298
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 2000, batch loss is 0.667521, total loss is 1460.179199
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 3000, batch loss is 0.650816, total loss is 2122.120361
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 4000, batch loss is 0.616259, total loss is 2743.238525
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 5000, batch loss is 0.784542, total loss is 3447.365723
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 6000, batch loss is 0.690846, total loss is 4196.209473
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 7000, batch loss is 0.687029, total loss is 4896.491699
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 8000, batch loss is 0.675314, total loss is 5552.817871
# -----------------------
# -----------------------
# Epoch 7 end: 18.168817281723022
# Validation loss: 912.1932373 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 1000, batch loss is 0.735501, total loss is 756.399292
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 2000, batch loss is 0.667749, total loss is 1464.545410
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 3000, batch loss is 0.654199, total loss is 2128.409668
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 4000, batch loss is 0.617223, total loss is 2750.980713
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 5000, batch loss is 0.781822, total loss is 3454.319336
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 6000, batch loss is 0.688512, total loss is 4200.726074
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 7000, batch loss is 0.686521, total loss is 4898.543457
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 8000, batch loss is 0.674834, total loss is 5552.503906
# -----------------------
# -----------------------
# Epoch 8 end: 18.301830530166626
# Validation loss: 910.7202759 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 1 KS: 4 SS: 2 LR: 1e-07
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.692469, total loss is 699.816711
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.691947, total loss is 1394.474609
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 3000, batch loss is 0.705782, total loss is 2083.663086
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 4000, batch loss is 0.655614, total loss is 2767.885498
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 5000, batch loss is 0.698535, total loss is 3463.196777
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 6000, batch loss is 0.704232, total loss is 4165.010254
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 7000, batch loss is 0.718474, total loss is 4862.760742
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 8000, batch loss is 0.683437, total loss is 5555.037598
# -----------------------
# -----------------------
# Epoch 0 end: 24.325642824172974
# Validation loss: 974.9611816 - F1 score: 0.4753999
# 0 class -> precision: 0.1958763 - recall: 0.3166667
# 1 class -> precision: 0.7793326 - recall: 0.6499102
# precision: 0.4876045 - recall: 0.4832885 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 0.692194, total loss is 699.647278
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.691612, total loss is 1394.245605
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 3000, batch loss is 0.705938, total loss is 2083.498535
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 4000, batch loss is 0.656081, total loss is 2767.910400
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 5000, batch loss is 0.697871, total loss is 3463.075684
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 6000, batch loss is 0.703751, total loss is 4164.509277
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 7000, batch loss is 0.717973, total loss is 4861.965332
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 8000, batch loss is 0.683344, total loss is 5553.977539
# -----------------------
# -----------------------
# Epoch 1 end: 18.69084405899048
# Validation loss: 974.7789917 - F1 score: 0.4759816
# 0 class -> precision: 0.1958333 - recall: 0.3133333
# 1 class -> precision: 0.7794433 - recall: 0.6535009
# precision: 0.4876383 - recall: 0.4834171 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 0.692096, total loss is 699.715698
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.691342, total loss is 1394.399658
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 3000, batch loss is 0.706053, total loss is 2083.741211
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 4000, batch loss is 0.656440, total loss is 2768.246338
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 5000, batch loss is 0.697357, total loss is 3463.294434
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 6000, batch loss is 0.703353, total loss is 4164.461426
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 7000, batch loss is 0.717561, total loss is 4861.675293
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 8000, batch loss is 0.683260, total loss is 5553.450684
# -----------------------
# -----------------------
# Epoch 2 end: 18.812950134277344
# Validation loss: 974.5902710 - F1 score: 0.4739275
# 0 class -> precision: 0.1923890 - recall: 0.3033333
# 1 class -> precision: 0.7778959 - recall: 0.6570916
# precision: 0.4851424 - recall: 0.4802124 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 0.691990, total loss is 699.786194
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.691058, total loss is 1394.546021
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 3000, batch loss is 0.706115, total loss is 2083.962646
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 4000, batch loss is 0.656771, total loss is 2768.546875
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 5000, batch loss is 0.696854, total loss is 3463.476318
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 6000, batch loss is 0.702976, total loss is 4164.399902
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 7000, batch loss is 0.717198, total loss is 4861.377441
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 8000, batch loss is 0.683157, total loss is 5552.929199
# -----------------------
# -----------------------
# Epoch 3 end: 18.70516037940979
# Validation loss: 974.4061279 - F1 score: 0.4771093
# 0 class -> precision: 0.1957447 - recall: 0.3066667
# 1 class -> precision: 0.7796610 - recall: 0.6606822
# precision: 0.4877028 - recall: 0.4836744 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 0.691882, total loss is 699.857056
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.690991, total loss is 1394.690796
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 3000, batch loss is 0.706190, total loss is 2084.183838
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 4000, batch loss is 0.657092, total loss is 2768.848145
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 5000, batch loss is 0.696352, total loss is 3463.671875
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 6000, batch loss is 0.702636, total loss is 4164.353516
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 7000, batch loss is 0.716848, total loss is 4861.109863
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 8000, batch loss is 0.683053, total loss is 5552.430176
# -----------------------
# -----------------------
# Epoch 4 end: 18.40316414833069
# Validation loss: 974.2272339 - F1 score: 0.4749337
# 0 class -> precision: 0.1927195 - recall: 0.3000000
# 1 class -> precision: 0.7782471 - recall: 0.6615799
# precision: 0.4854833 - recall: 0.4807899 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 1000, batch loss is 0.691771, total loss is 699.922546
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 2000, batch loss is 0.691018, total loss is 1394.829590
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 3000, batch loss is 0.706258, total loss is 2084.386475
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 4000, batch loss is 0.657409, total loss is 2769.118408
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 5000, batch loss is 0.695830, total loss is 3463.834961
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 6000, batch loss is 0.702308, total loss is 4164.287598
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 7000, batch loss is 0.716522, total loss is 4860.836426
# -----------------------
# -----------------------
# Train - Epoch 5 - batch 8000, batch loss is 0.682921, total loss is 5551.946289
# -----------------------
# -----------------------
# Epoch 5 end: 18.773905992507935
# Validation loss: 974.0572510 - F1 score: 0.4722794
# 0 class -> precision: 0.1892473 - recall: 0.2933333
# 1 class -> precision: 0.7766070 - recall: 0.6615799
# precision: 0.4829271 - recall: 0.4774566 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 1000, batch loss is 0.691672, total loss is 699.979797
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 2000, batch loss is 0.691028, total loss is 1394.948364
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 3000, batch loss is 0.706296, total loss is 2084.562500
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 4000, batch loss is 0.657713, total loss is 2769.355713
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 5000, batch loss is 0.695308, total loss is 3463.967773
# -----------------------
# -----------------------
# ...
# 0 class -> precision: 0.2160714 - recall: 0.8066667
# 1 class -> precision: 0.8027211 - recall: 0.2118492
# precision: 0.5093963 - recall: 0.5092579 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 1000, batch loss is 0.680694, total loss is 662.086182
# -----------------------
# -----------------------
# Train - Epoch 6 - batch 2000, batch loss is 0.731132, total loss is 1381.055298
# -----------------------
# -----------------------
# Epoch 6 end: 6.907573223114014
# Validation loss: 249.4916077 - F1 score: 0.3471475
# 0 class -> precision: 0.2160438 - recall: 0.7900000
# 1 class -> precision: 0.8012618 - recall: 0.2280072
# precision: 0.5086528 - recall: 0.5090036 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 1000, batch loss is 0.681840, total loss is 663.192566
# -----------------------
# -----------------------
# Train - Epoch 7 - batch 2000, batch loss is 0.729680, total loss is 1381.087646
# -----------------------
# -----------------------
# Epoch 7 end: 7.058191776275635
# Validation loss: 249.2254791 - F1 score: 0.3609000
# 0 class -> precision: 0.2195349 - recall: 0.7866667
# 1 class -> precision: 0.8112094 - recall: 0.2468582
# precision: 0.5153722 - recall: 0.5167624 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 1000, batch loss is 0.682939, total loss is 664.253418
# -----------------------
# -----------------------
# Train - Epoch 8 - batch 2000, batch loss is 0.728281, total loss is 1381.116455
# -----------------------
# -----------------------
# Epoch 8 end: 7.056479215621948
# Validation loss: 248.9701385 - F1 score: 0.3689179
# 0 class -> precision: 0.2209632 - recall: 0.7800000
# 1 class -> precision: 0.8140845 - recall: 0.2594255
# precision: 0.5175238 - recall: 0.5197127 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 9 - batch 1000, batch loss is 0.684016, total loss is 665.269897
# -----------------------
# -----------------------
# Train - Epoch 9 - batch 2000, batch loss is 0.726937, total loss is 1381.140747
# -----------------------
# -----------------------
# Epoch 9 end: 7.020796060562134
# Validation loss: 248.7260284 - F1 score: 0.3778316
# 0 class -> precision: 0.2212560 - recall: 0.7633333
# 1 class -> precision: 0.8126649 - recall: 0.2764811
# precision: 0.5169605 - recall: 0.5199072 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 10 - batch 1000, batch loss is 0.685039, total loss is 666.243469
# -----------------------
# -----------------------
# Train - Epoch 10 - batch 2000, batch loss is 0.725652, total loss is 1381.163574
# -----------------------
# -----------------------
# Epoch 10 end: 7.152132987976074
# Validation loss: 248.4920044 - F1 score: 0.3878409
# 0 class -> precision: 0.2225519 - recall: 0.7500000
# 1 class -> precision: 0.8138958 - recall: 0.2944345
# precision: 0.5182239 - recall: 0.5222172 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 11 - batch 1000, batch loss is 0.686025, total loss is 667.174072
# -----------------------
# -----------------------
# Train - Epoch 11 - batch 2000, batch loss is 0.724409, total loss is 1381.175537
# -----------------------
# -----------------------
# Epoch 11 end: 7.011324882507324
# Validation loss: 248.2673798 - F1 score: 0.3937216
# 0 class -> precision: 0.2225579 - recall: 0.7366667
# 1 class -> precision: 0.8123515 - recall: 0.3070018
# precision: 0.5174547 - recall: 0.5218342 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 12 - batch 1000, batch loss is 0.686966, total loss is 668.064331
# -----------------------
# -----------------------
# Train - Epoch 12 - batch 2000, batch loss is 0.723204, total loss is 1381.182617
# -----------------------
# -----------------------
# Epoch 12 end: 6.930677652359009
# Validation loss: 248.0507050 - F1 score: 0.3938859
# 0 class -> precision: 0.2190379 - recall: 0.7133333
# 1 class -> precision: 0.8032037 - recall: 0.3150808
# precision: 0.5111208 - recall: 0.5142071 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 13 - batch 1000, batch loss is 0.687867, total loss is 668.919128
# -----------------------
# -----------------------
# Train - Epoch 13 - batch 2000, batch loss is 0.722045, total loss is 1381.184570
# -----------------------
# -----------------------
# Epoch 13 end: 7.211590528488159
# Validation loss: 247.8427429 - F1 score: 0.4045863
# 0 class -> precision: 0.2214061 - recall: 0.7033333
# 1 class -> precision: 0.8069414 - recall: 0.3339318
# precision: 0.5141738 - recall: 0.5186326 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 14 - batch 1000, batch loss is 0.688729, total loss is 669.735779
# -----------------------
# -----------------------
# Train - Epoch 14 - batch 2000, batch loss is 0.720923, total loss is 1381.179932
# -----------------------
# -----------------------
# Epoch 14 end: 7.100259065628052
# Validation loss: 247.6426697 - F1 score: 0.4078727
# 0 class -> precision: 0.2200855 - recall: 0.6866667
# 1 class -> precision: 0.8033473 - recall: 0.3447038
# precision: 0.5117164 - recall: 0.5156852 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 15 - batch 1000, batch loss is 0.689559, total loss is 670.522461
# -----------------------
# -----------------------
# Train - Epoch 15 - batch 2000, batch loss is 0.719841, total loss is 1381.172974
# -----------------------
# -----------------------
# Epoch 15 end: 7.52288031578064
# Validation loss: 247.4498444 - F1 score: 0.4150966
# 0 class -> precision: 0.2213740 - recall: 0.6766667
# 1 class -> precision: 0.8048290 - recall: 0.3590664
# precision: 0.5131015 - recall: 0.5178665 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 16 - batch 1000, batch loss is 0.690349, total loss is 671.273682
# -----------------------
# -----------------------
# Train - Epoch 16 - batch 2000, batch loss is 0.718793, total loss is 1381.160278
# -----------------------
# -----------------------
# Epoch 16 end: 7.329522371292114
# Validation loss: 247.2637634 - F1 score: 0.4173788
# 0 class -> precision: 0.2207506 - recall: 0.6666667
# 1 class -> precision: 0.8031496 - recall: 0.3662478
# precision: 0.5119501 - recall: 0.5164572 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 17 - batch 1000, batch loss is 0.691104, total loss is 671.990173
# -----------------------
# -----------------------
# Train - Epoch 17 - batch 2000, batch loss is 0.717787, total loss is 1381.142578
# -----------------------
# -----------------------
# Epoch 17 end: 7.135074615478516
# Validation loss: 247.0857086 - F1 score: 0.4219027
# 0 class -> precision: 0.2220982 - recall: 0.6633333
# 1 class -> precision: 0.8050193 - recall: 0.3743268
# precision: 0.5135588 - recall: 0.5188300 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 18 - batch 1000, batch loss is 0.691835, total loss is 672.676575
# -----------------------
# -----------------------
# Train - Epoch 18 - batch 2000, batch loss is 0.716818, total loss is 1381.119995
# -----------------------
# -----------------------
# Epoch 18 end: 7.117355823516846
# Validation loss: 246.9141846 - F1 score: 0.4290976
# 0 class -> precision: 0.2231121 - recall: 0.6500000
# 1 class -> precision: 0.8055556 - recall: 0.3904847
# precision: 0.5143338 - recall: 0.5202424 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 19 - batch 1000, batch loss is 0.692534, total loss is 673.334839
# -----------------------
# -----------------------
# Train - Epoch 19 - batch 2000, batch loss is 0.715884, total loss is 1381.096680
# -----------------------
# -----------------------
# Epoch 19 end: 7.028820514678955
# Validation loss: 246.7489166 - F1 score: 0.4288173
# 0 class -> precision: 0.2204176 - recall: 0.6333333
# 1 class -> precision: 0.8007246 - recall: 0.3967684
# precision: 0.5105711 - recall: 0.5150509 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 20 - batch 1000, batch loss is 0.693191, total loss is 673.963989
# -----------------------
# -----------------------
# Train - Epoch 20 - batch 2000, batch loss is 0.714989, total loss is 1381.066895
# -----------------------
# -----------------------
# Epoch 20 end: 7.0578553676605225
# Validation loss: 246.5895996 - F1 score: 0.4348392
# 0 class -> precision: 0.2215640 - recall: 0.6233333
# 1 class -> precision: 0.8017544 - recall: 0.4102334
# precision: 0.5116592 - recall: 0.5167834 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 21 - batch 1000, batch loss is 0.693818, total loss is 674.569275
# -----------------------
# -----------------------
# Train - Epoch 21 - batch 2000, batch loss is 0.714127, total loss is 1381.035278
# -----------------------
# -----------------------
# Epoch 21 end: 7.227678060531616
# Validation loss: 246.4358368 - F1 score: 0.4378794
# 0 class -> precision: 0.2214200 - recall: 0.6133333
# 1 class -> precision: 0.8010292 - recall: 0.4192101
# precision: 0.5112246 - recall: 0.5162717 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 22 - batch 1000, batch loss is 0.694410, total loss is 675.150024
# -----------------------
# -----------------------
# Train - Epoch 22 - batch 2000, batch loss is 0.713295, total loss is 1381.003052
# -----------------------
# -----------------------
# Epoch 22 end: 7.581415414810181
# Validation loss: 246.2879486 - F1 score: 0.4377469
# 0 class -> precision: 0.2177122 - recall: 0.5900000
# 1 class -> precision: 0.7953411 - recall: 0.4290844
# precision: 0.5065266 - recall: 0.5095422 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 23 - batch 1000, batch loss is 0.694967, total loss is 675.705872
# -----------------------
# -----------------------
# Train - Epoch 23 - batch 2000, batch loss is 0.712491, total loss is 1380.964966
# -----------------------
# -----------------------
# Epoch 23 end: 7.577978610992432
# Validation loss: 246.1464539 - F1 score: 0.4431957
# 0 class -> precision: 0.2192982 - recall: 0.5833333
# 1 class -> precision: 0.7970779 - recall: 0.4407540
# precision: 0.5081881 - recall: 0.5120437 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 24 - batch 1000, batch loss is 0.695500, total loss is 676.235901
# -----------------------
# -----------------------
# Train - Epoch 24 - batch 2000, batch loss is 0.711726, total loss is 1380.925659
# -----------------------
# -----------------------
# Epoch 24 end: 7.463612079620361
# Validation loss: 246.0101318 - F1 score: 0.4435238
# 0 class -> precision: 0.2168367 - recall: 0.5666667
# 1 class -> precision: 0.7936508 - recall: 0.4488330
# precision: 0.5052438 - recall: 0.5077499 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 25 - batch 1000, batch loss is 0.696017, total loss is 676.742371
# -----------------------
# -----------------------
# Train - Epoch 25 - batch 2000, batch loss is 0.710980, total loss is 1380.878662
# -----------------------
# -----------------------
# Epoch 25 end: 7.448807239532471
# Validation loss: 245.8781433 - F1 score: 0.4484989
# 0 class -> precision: 0.2193548 - recall: 0.5666667
# 1 class -> precision: 0.7965571 - recall: 0.4569120
# precision: 0.5079560 - recall: 0.5117893 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 26 - batch 1000, batch loss is 0.696502, total loss is 677.228882
# -----------------------
# -----------------------
# Train - Epoch 26 - batch 2000, batch loss is 0.710228, total loss is 1380.832031
# -----------------------
# -----------------------
# Epoch 26 end: 7.334184169769287
# Validation loss: 245.7515869 - F1 score: 0.4504475
# 0 class -> precision: 0.2193211 - recall: 0.5600000
# 1 class -> precision: 0.7962963 - recall: 0.4631957
# precision: 0.5078087 - recall: 0.5115978 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 27 - batch 1000, batch loss is 0.696962, total loss is 677.691589
# -----------------------
# -----------------------
# Train - Epoch 27 - batch 2000, batch loss is 0.709501, total loss is 1380.779907
# -----------------------
# -----------------------
# Epoch 27 end: 7.299793004989624
# Validation loss: 245.6291504 - F1 score: 0.4566056
# 0 class -> precision: 0.2220745 - recall: 0.5566667
# 1 class -> precision: 0.7990937 - recall: 0.4748654
# precision: 0.5105841 - recall: 0.5157660 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 28 - batch 1000, batch loss is 0.697399, total loss is 678.135437
# -----------------------
# -----------------------
# Train - Epoch 28 - batch 2000, batch loss is 0.708803, total loss is 1380.728027
# -----------------------
# -----------------------
# Epoch 28 end: 7.3083271980285645
# Validation loss: 245.5116882 - F1 score: 0.4615156
# 0 class -> precision: 0.2247645 - recall: 0.5566667
# 1 class -> precision: 0.8017884 - recall: 0.4829443
# precision: 0.5132764 - recall: 0.5198055 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 29 - batch 1000, batch loss is 0.697806, total loss is 678.556519
# -----------------------
# -----------------------
# Train - Epoch 29 - batch 2000, batch loss is 0.708126, total loss is 1380.667114
# -----------------------
# -----------------------
# Epoch 29 end: 6.88669753074646
# Validation loss: 245.3986664 - F1 score: 0.4634651
# 0 class -> precision: 0.2243502 - recall: 0.5466667
# 1 class -> precision: 0.8008785 - recall: 0.4910233
# precision: 0.5126143 - recall: 0.5188450 - MACRO
# -----------------------
# -----------------------
# -----------------------
# Starting training for BS: 4 KS: 16 SS: 2 LR: 1e-08
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 1000, batch loss is 0.985339, total loss is 991.778564
# -----------------------
# -----------------------
# Train - Epoch 0 - batch 2000, batch loss is 0.479987, total loss is 1513.531860
# -----------------------
# -----------------------
# Epoch 0 end: 9.654153108596802
# Validation loss: 203.8153839 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 1000, batch loss is 0.984374, total loss is 990.902527
# -----------------------
# -----------------------
# Train - Epoch 1 - batch 2000, batch loss is 0.480644, total loss is 1513.066162
# -----------------------
# -----------------------
# Epoch 1 end: 7.26716685295105
# Validation loss: 203.9056854 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 1000, batch loss is 0.983476, total loss is 989.940735
# -----------------------
# -----------------------
# Train - Epoch 2 - batch 2000, batch loss is 0.481252, total loss is 1512.489380
# -----------------------
# -----------------------
# Epoch 2 end: 7.27925705909729
# Validation loss: 203.9884491 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 1000, batch loss is 0.982589, total loss is 989.017578
# -----------------------
# -----------------------
# Train - Epoch 3 - batch 2000, batch loss is 0.481851, total loss is 1511.942017
# -----------------------
# -----------------------
# Epoch 3 end: 7.2558434009552
# Validation loss: 204.0699463 - F1 score: 0.4406646
# 0 class -> precision: 0.0000000 - recall: 0.0000000
# 1 class -> precision: 0.7878359 - recall: 1.0000000
# precision: 0.3939180 - recall: 0.5000000 - MACRO
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 1000, batch loss is 0.981705, total loss is 988.102661
# -----------------------
# -----------------------
# Train - Epoch 4 - batch 2000, batch loss is 0.482450, total loss is 1511.406738
# -----------------------
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
